# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Pretty healthy as a snack or part of meals.
#
#     Key perks:
#     - Good source of potassium (supports heart and fluids) and vitamin B6
#     - Dietary fiber (aids digestion) and vitamin C
#     - Quick energy from natural sugars; portable and affordable
#     - Low in fat and protein, so pair with protein/fat for staying power
#
#     Things to watch:
#     - Moderate sugar content; portion if watching blood sugar (1 medium banana is ~105 calories, ~27 g carbs)
#     - Ripe bananas are sweeter; unripe have resistant starch (gentler on blood sugar)
#
#     Bottom line: bananas are a nutritious, convenient choice when eaten in standard portions.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Overall, bananas are healthy.
#
# Key benefits:
# - Nutrients: good source of potassium, vitamin B6, vitamin C, fiber.
# - Low in fat; ~90–110 calories per medium banana.
# - Support heart health, digestion, and steady energy.
#
# Things to consider:
# - Higher in natural sugars; portion size matters for blood sugar control.
# - If you have kidney disease or potassium restrictions, monitor intake.
# - Overripe bananas are softer and sweeter; some people prefer them for digestion or baking.
#
# Tip: one medium banana is a convenient, balanced snack.

# %% [markdown]
# _Good Job!_
